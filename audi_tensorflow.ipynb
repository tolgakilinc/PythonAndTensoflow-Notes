# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame = pd.read_csv("audi.csv")

# %%
dataFrame.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10668.000000   10668.000000   10668.000000  10668.000000  10668.000000
# mean    2017.100675   22896.685039   24827.244001    126.011436     50.770022
# std        2.167494   11714.841888   23505.257205     67.170294     12.949782
# min     1997.000000    1490.000000       1.000000      0.000000     18.900000
# 25%     2016.000000   15130.750000    5968.750000    125.000000     40.900000
# 50%     2017.000000   20200.000000   19000.000000    145.000000     49.600000
# 75%     2019.000000   27990.000000   36464.500000    145.000000     58.900000
# max     2020.000000  145000.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10668.000000
# mean       1.930709
# std        0.602957
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %%
dataFrame.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure()
sbn.displot(dataFrame["price"])

# %%
sbn.countplot(dataFrame["year"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# mpg          -0.600334
# mileage      -0.535357
# tax           0.356157
# engineSize    0.591262
# year          0.592581
# price         1.000000
# Name: price, dtype: float64

# %%
sbn.scatterplot(x="mileage",y="price",data=dataFrame)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
len(dataFrame)
# Out:
# 10668

# %%
len(dataFrame) * 0.01
# Out:
# 106.68

# %%
yuzdeDoksanDokuzVeri = dataFrame.sort_values("price",ascending=False).iloc[106:]

# %%
yuzdeDoksanDokuzVeri
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 7221     A5  2020  59995    Semi-Auto     2000   Diesel  150  40.9         3.0
# 222      Q7  2019  59995    Automatic       10   Diesel  145  33.2         3.0
# 5129     Q7  2019  59990    Automatic     3988   Diesel  145  32.8         3.0
# 4100    RS4  2019  59990    Automatic     5121   Petrol  145  29.1         2.9
# 4669     Q7  2020  59990    Semi-Auto      799   Diesel  145  33.2         3.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 7404     A3  2009   2490       Manual   152034   Diesel  150  55.4         1.9
# 10108    TT  2002   1990       Manual   131925   Petrol  325  30.1         1.8
# 7795     A3  2005   1975       Manual   104000   Petrol  240  38.1         2.0
# 10552    A4  2004   1699       Manual   110000   Diesel  315  36.2         2.5
# 10588    A3  2003   1490    Automatic   101000   Diesel  240  44.5         1.9
#
# ...

# %%
yuzdeDoksanDokuzVeri.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  10562.000000  10562.000000   10562.000000  10562.000000  10562.000000
# mean    2017.079909  22331.520640   25012.921038    125.730449     50.977978
# std        2.166547  10079.220417   23540.812433     67.199298     12.837371
# min     1997.000000   1490.000000       5.000000      0.000000     18.900000
# 25%     2016.000000  15000.000000    6000.000000    125.000000     40.900000
# 50%     2017.000000  20000.000000   19298.000000    145.000000     49.600000
# 75%     2019.000000  27847.750000   36715.000000    145.000000     58.900000
# max     2020.000000  59995.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10562.000000
# mean       1.912412
# std        0.571433
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %%
yuzdeDoksanDokuzVeri
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 7221     A5  2020  59995    Semi-Auto     2000   Diesel  150  40.9         3.0
# 222      Q7  2019  59995    Automatic       10   Diesel  145  33.2         3.0
# 5129     Q7  2019  59990    Automatic     3988   Diesel  145  32.8         3.0
# 4100    RS4  2019  59990    Automatic     5121   Petrol  145  29.1         2.9
# 4669     Q7  2020  59990    Semi-Auto      799   Diesel  145  33.2         3.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 7404     A3  2009   2490       Manual   152034   Diesel  150  55.4         1.9
# 10108    TT  2002   1990       Manual   131925   Petrol  325  30.1         1.8
# 7795     A3  2005   1975       Manual   104000   Petrol  240  38.1         2.0
# 10552    A4  2004   1699       Manual   110000   Diesel  315  36.2         2.5
# 10588    A3  2003   1490    Automatic   101000   Diesel  240  44.5         1.9
#
# ...

# %%
yuzdeDoksanDokuzVeri = dataFrame

# %%
dataFrame = dataFrame.drop(columns=["model","transmission","fuelType"],axis=1)

# %%
y = dataFrame["price"].values
x = dataFrame.drop(columns=["price"],axis=1).values

# %%
x
# Out:
# array([[2.0170e+03, 1.5735e+04, 1.5000e+02, 5.5400e+01, 1.4000e+00],
#        [2.0160e+03, 3.6203e+04, 2.0000e+01, 6.4200e+01, 2.0000e+00],
#        [2.0160e+03, 2.9946e+04, 3.0000e+01, 5.5400e+01, 1.4000e+00],
#        ...,
#        [2.0200e+03, 6.0900e+02, 1.5000e+02, 4.9600e+01, 1.0000e+00],
#        [2.0170e+03, 8.6460e+03, 1.5000e+02, 4.7900e+01, 1.4000e+00],
#        [2.0160e+03, 1.1855e+04, 1.5000e+02, 4.7900e+01, 1.4000e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
len(x_test)
# Out:
# 3201

# %%
x_test
# Out:
# array([[2.0190e+03, 7.5000e+03, 1.4500e+02, 4.7900e+01, 2.0000e+00],
#        [2.0180e+03, 8.7680e+03, 1.5000e+02, 5.1400e+01, 1.0000e+00],
#        [2.0190e+03, 9.1000e+03, 1.4500e+02, 4.6300e+01, 2.0000e+00],
#        ...,
#        [2.0200e+03, 1.0000e+03, 1.4500e+02, 4.4800e+01, 1.5000e+00],
#        [2.0190e+03, 9.1260e+03, 1.4500e+02, 3.3600e+01, 3.0000e+00],
#        [2.0150e+03, 5.2891e+04, 2.0500e+02, 4.7900e+01, 3.0000e+00]])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (7467, 5)

# %%
model = Sequential()
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(1))

model.compile(optimizer="adam",loss="mse")

# %%
model.fit(x=x_train,y=y_train,validation_data=(x_test,y_test),batch_size=250,epochs=300)
# Out:
# Epoch 1/300
# 30/30 [==============================] - 1s 7ms/step - loss: 666109632.0000 - val_loss: 650657280.0000
# Epoch 2/300
# 30/30 [==============================] - 0s 2ms/step - loss: 666089280.0000 - val_loss: 650629760.0000
# Epoch 3/300
# 30/30 [==============================] - 0s 2ms/step - loss: 666049024.0000 - val_loss: 650571200.0000
# Epoch 4/300
# 30/30 [==============================] - 0s 2ms/step - loss: 665957376.0000 - val_loss: 650430528.0000
# Epoch 5/300
# 30/30 [==============================] - 0s 2ms/step - loss: 665731776.0000 - val_loss: 650086656.0000
# Epoch 6/300
# 30/30 [==============================] - 0s 2ms/step - loss: 665191872.0000 - val_loss: 649272320.0000
# Epoch 7/300
# 30/30 [==============================] - 0s 2ms/step - loss: 663959360.0000 - val_loss: 647506432.0000
# Epoch 8/300
# 30/30 [==============================] - 0s 2ms/step - loss: 661437568.0000 - val_loss: 644033728.0000
# Epoch 9/300
# ...

# %%
kayipVerisi = pd.DataFrame(model.history.history)

# %%
kayipVerisi.head()
# Out:
#           loss     val_loss
# 0  666109632.0  650657280.0
# 1  666089280.0  650629760.0
# 2  666049024.0  650571200.0
# 3  665957376.0  650430528.0
# 4  665731776.0  650086656.0

# %%
kayipVerisi.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
tahminDizisi = model.predict(x_test)
# Out:
# 101/101 [==============================] - 0s 589us/step

# %%
tahminDizisi
# Out:
# array([[27732.23 ],
#        [18828.67 ],
#        [27897.65 ],
#        ...,
#        [26969.094],
#        [48325.703],
#        [21199.357]], dtype=float32)

# %%
mean_absolute_error(y_test,tahminDizisi)
# Out:
# 2624.6064084740365

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10668.000000   10668.000000   10668.000000  10668.000000  10668.000000
# mean    2017.100675   22896.685039   24827.244001    126.011436     50.770022
# std        2.167494   11714.841888   23505.257205     67.170294     12.949782
# min     1997.000000    1490.000000       1.000000      0.000000     18.900000
# 25%     2016.000000   15130.750000    5968.750000    125.000000     40.900000
# 50%     2017.000000   20200.000000   19000.000000    145.000000     49.600000
# 75%     2019.000000   27990.000000   36464.500000    145.000000     58.900000
# max     2020.000000  145000.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10668.000000
# mean       1.930709
# std        0.602957
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %%
plt.scatter(y_test,tahminDizisi)
plt.plot(y_test,y_test,"g-*")

# %%
dataFrame
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 0      2017  12500    15735  150  55.4         1.4
# 1      2016  16500    36203   20  64.2         2.0
# 2      2016  11000    29946   30  55.4         1.4
# 3      2017  16800    25952  145  67.3         2.0
# 4      2019  17300     1998  145  49.6         1.0
# ...     ...    ...      ...  ...   ...         ...
# 10663  2020  16999     4018  145  49.6         1.0
# 10664  2020  16999     1978  150  49.6         1.0
# 10665  2020  17199      609  150  49.6         1.0
# 10666  2017  19499     8646  150  47.9         1.4
# 10667  2016  15999    11855  150  47.9         1.4
#
# [10668 rows x 6 columns]

# %%
dataFrame.iloc[2]
# Out:
# year           2016.0
# price         11000.0
# mileage       29946.0
# tax              30.0
# mpg              55.4
# engineSize        1.4
# Name: 2, dtype: float64

# %%
dataFrame
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 0      2017  12500    15735  150  55.4         1.4
# 1      2016  16500    36203   20  64.2         2.0
# 2      2016  11000    29946   30  55.4         1.4
# 3      2017  16800    25952  145  67.3         2.0
# 4      2019  17300     1998  145  49.6         1.0
# ...     ...    ...      ...  ...   ...         ...
# 10663  2020  16999     4018  145  49.6         1.0
# 10664  2020  16999     1978  150  49.6         1.0
# 10665  2020  17199      609  150  49.6         1.0
# 10666  2017  19499     8646  150  47.9         1.4
# 10667  2016  15999    11855  150  47.9         1.4
#
# [10668 rows x 6 columns]

# %%
yeniArabaDf = dataFrame.drop("price",axis=1).iloc[2]

# %%
type(yeniArabaDf)
# Out:
# pandas.core.series.Series

# %%
yeniArabaDf = scaler.transform(yeniArabaDf.values.reshape(-1,5))

# %%
yeniArabaDf
# Out:
# array([[0.77777778, 0.09270927, 0.05172414, 0.21360947, 0.22222222]])

# %%
model.predict(yeniArabaDf)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# array([[14577.02]], dtype=float32)

# %%
yeniArabaDf
# Out:
# array([[0.77777778, 0.09270927, 0.05172414, 0.21360947, 0.22222222]])
